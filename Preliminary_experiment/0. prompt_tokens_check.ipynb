# %%
import re

forder = "user_prompts"
purpose = "with_negative"

output_metadata = f"{forder}/{purpose}/metadata/output_metadata.txt"

# %% [markdown]
# ### token수만 계산

# %%
def process_user_data(filename, start_user, end_user):
    input_tokens_sum = 0
    output_tokens_sum = 0
    user_data = []
    
    with open(filename, 'r') as file:
        lines = file.readlines()
        start_found = False
        
        for line in lines:
            if start_user in line:
                start_found = True
            
            if start_found:
                user_data.append(line.strip())
                parts = line.split()
                input_tokens = int(parts[5])
                output_tokens = int(parts[8])
                input_tokens_sum += input_tokens
                output_tokens_sum += output_tokens
                
            if end_user in line:
                break

    # 결과 출력
    for data in user_data:
        print(data)
    print(f"\nInput Tokens 합: {input_tokens_sum}")
    print(f"Output Tokens 합: {output_tokens_sum}")

# 파일 경로 및 USER 범위 지정
start_user = 'U1'
end_user = 'U50'
process_user_data(output_metadata, start_user, end_user)
# Out:
# User ID: U1    Input Tokens: 2289   Output Tokens: 75    History 수: 18   Question 수: 4
# User ID: U2    Input Tokens: 2411   Output Tokens: 132   History 수: 16   Question 수: 7
# User ID: U3    Input Tokens: 2115   Output Tokens: 132   History 수: 14   Question 수: 7
# User ID: U4    Input Tokens: 1838   Output Tokens: 75    History 수: 14   Question 수: 4
# User ID: U5    Input Tokens: 3135   Output Tokens: 265   History 수: 17   Question 수: 14
# User ID: U6    Input Tokens: 3702   Output Tokens: 379   History 수: 17   Question 수: 20
# User ID: U7    Input Tokens: 5803   Output Tokens: 474   History 수: 34   Question 수: 25
# User ID: U8    Input Tokens: 1876   Output Tokens: 189   History 수: 9    Question 수: 10
# User ID: U9    Input Tokens: 2430   Output Tokens: 75    History 수: 19   Question 수: 4
# User ID: U10   Input Tokens: 2498   Output Tokens: 189   History 수: 15   Question 수: 10
# User ID: U11   Input Tokens: 4602   Output Tokens: 379   History 수: 27   Question 수: 20
# User ID: U12   Input Tokens: 3360   Output Tokens: 322   History 수: 16   Question 수: 17
# User ID: U13   Input Tokens: 2704   Output Tokens: 284   History 수: 12   Question 수: 15
# User ID: U14   Input Tokens: 2833   Output Tokens: 170   History 수: 18   Question 수: 9
# User ID: U15   Input Tokens: 1662   Output Tokens: 132   History 수: 10   Question 수: 7
# User ID: U16   Input Tokens: 3023   Output Tokens: 132   History 수: 23   Question 수: 7
# User ID: U17   Input Tokens: 1877   Output Tokens: 303   History 수: 4    Question 수: 16
# User ID: U18   Input Tokens: 4322   Output Tokens: 436   History 수: 21   Question 수: 23
# User ID: U19   Input Tokens: 3211   Output Tokens: 303   History 수: 16   Question 수: 16
# User ID: U20   Input Tokens: 1726   Output Tokens: 151   History 수: 9    Question 수: 8
# User ID: U21   Input Tokens: 3569   Output Tokens: 303   History 수: 20   Question 수: 16
# User ID: U22   Input Tokens: 5824   Output Tokens: 474   History 수: 33   Question 수: 25
# User ID: U23   Input Tokens: 3611   Output Tokens: 436   History 수: 14   Question 수: 23
# User ID: U24   Input Tokens: 3282   Output Tokens: 341   History 수: 16   Question 수: 18
# User ID: U25   Input Tokens: 2361   Output Tokens: 246   History 수: 11   Question 수: 13
# User ID: U26   Input Tokens: 4543   Output Tokens: 227   History 수: 32   Question 수: 12
# User ID: U27   Input Tokens: 1769   Output Tokens: 113   History 수: 11   Question 수: 6
# User ID: U28   Input Tokens: 4293   Output Tokens: 379   History 수: 23   Question 수: 20
# User ID: U29   Input Tokens: 1961   Output Tokens: 170   History 수: 10   Question 수: 9
# User ID: U30   Input Tokens: 1039   Output Tokens: 18    History 수: 9    Question 수: 1
# User ID: U31   Input Tokens: 3440   Output Tokens: 341   History 수: 17   Question 수: 18
# User ID: U32   Input Tokens: 1898   Output Tokens: 94    History 수: 15   Question 수: 5
# User ID: U33   Input Tokens: 3421   Output Tokens: 303   History 수: 18   Question 수: 16
# User ID: U34   Input Tokens: 2710   Output Tokens: 284   History 수: 12   Question 수: 15
# User ID: U35   Input Tokens: 2024   Output Tokens: 379   History 수: 2    Question 수: 20
# User ID: U36   Input Tokens: 2900   Output Tokens: 246   History 수: 16   Question 수: 13
# User ID: U37   Input Tokens: 3967   Output Tokens: 360   History 수: 21   Question 수: 19
# User ID: U38   Input Tokens: 4498   Output Tokens: 322   History 수: 28   Question 수: 17
# User ID: U39   Input Tokens: 2011   Output Tokens: 94    History 수: 14   Question 수: 5
# User ID: U40   Input Tokens: 3128   Output Tokens: 360   History 수: 13   Question 수: 19
# User ID: U41   Input Tokens: 3313   Output Tokens: 322   History 수: 17   Question 수: 17
# User ID: U42   Input Tokens: 1678   Output Tokens: 170   History 수: 8    Question 수: 9
# User ID: U43   Input Tokens: 2583   Output Tokens: 246   History 수: 13   Question 수: 13
# User ID: U44   Input Tokens: 2028   Output Tokens: 189   History 수: 10   Question 수: 10
# User ID: U45   Input Tokens: 828    Output Tokens: 18    History 수: 7    Question 수: 1
# User ID: U46   Input Tokens: 1395   Output Tokens: 37    History 수: 11   Question 수: 2
# User ID: U47   Input Tokens: 3195   Output Tokens: 284   History 수: 17   Question 수: 15
# User ID: U48   Input Tokens: 1953   Output Tokens: 151   History 수: 11   Question 수: 8
# User ID: U49   Input Tokens: 2128   Output Tokens: 170   History 수: 12   Question 수: 9
# User ID: U50   Input Tokens: 1809   Output Tokens: 151   History 수: 10   Question 수: 8
#
# Input Tokens 합: 140576
# Output Tokens 합: 11825

# %% [markdown]
# ### token수 오름차순 정렬 (상위 N개)

# %%
# ID 범위를 지정
min_id = 1001
max_id = 1500
num_range = 50

entries = []
with open(output_metadata, 'r', encoding='utf-8') as file:
    for line in file:
        # 사용자 데이터 패턴에 맞는지 확인
        match = re.match(r'User ID: U(\d+)\s+Input Tokens: (\d+)\s+Output Tokens: (\d+)\s+History 수: (\d+)\s+Question 수: (\d+)', line)
        if match:
            user_id = int(match.group(1))
            if min_id <= user_id <= max_id:
                input_tokens = int(match.group(2))
                output_tokens = int(match.group(3))
                history_count = int(match.group(4))
                question_count = int(match.group(5))
                entries.append({
                    'User ID': user_id,
                    'Input Tokens': input_tokens,
                    'Output Tokens': output_tokens,
                    'History 수': history_count,
                    'Question 수': question_count
                })
        elif line.startswith('Total Input Tokens:'):
            # 총합 부분에 도달하면 루프 종료
            break

# Input Tokens를 기준으로 오름차순 정렬
sorted_entries = sorted(entries, key=lambda x: x['Input Tokens'])

# 최대 50개의 결과를 저장
top_entries = sorted_entries[:num_range]

# 상위 50개의 결과 출력
temp = []
for idx, entry in enumerate(top_entries, 1):
    print(f"{idx}. ID: {entry['User ID']}  Input Tokens: {entry['Input Tokens']}  Output Tokens: {entry['Output Tokens']}   History 수: {entry['History 수']}   Question 수: {entry['Question 수']}")
    temp.append(entry['User ID'])

# 총합 계산
total_input_tokens = sum(entry['Input Tokens'] for entry in top_entries)
total_output_tokens = sum(entry['Output Tokens'] for entry in top_entries)

# 총합 출력
print(f"\nTotal Input Tokens: {total_input_tokens}")
print(f"Total Output Tokens: {total_output_tokens}\n")
print(f"list = {temp}")
# Out:
# 1. ID: 1327  Input Tokens: 833  Output Tokens: 18   History 수: 7   Question 수: 1
# 2. ID: 1280  Input Tokens: 1059  Output Tokens: 94   History 수: 5   Question 수: 5
# 3. ID: 1448  Input Tokens: 1059  Output Tokens: 132   History 수: 4   Question 수: 7
# 4. ID: 1005  Input Tokens: 1107  Output Tokens: 94   History 수: 6   Question 수: 5
# 5. ID: 1019  Input Tokens: 1121  Output Tokens: 132   History 수: 4   Question 수: 7
# 6. ID: 1044  Input Tokens: 1156  Output Tokens: 37   History 수: 9   Question 수: 2
# 7. ID: 1425  Input Tokens: 1175  Output Tokens: 113   History 수: 6   Question 수: 6
# 8. ID: 1496  Input Tokens: 1199  Output Tokens: 132   History 수: 5   Question 수: 7
# 9. ID: 1295  Input Tokens: 1216  Output Tokens: 56   History 수: 9   Question 수: 3
# 10. ID: 1194  Input Tokens: 1245  Output Tokens: 94   History 수: 7   Question 수: 5
# 11. ID: 1208  Input Tokens: 1261  Output Tokens: 94   History 수: 7   Question 수: 5
# 12. ID: 1074  Input Tokens: 1270  Output Tokens: 113   History 수: 7   Question 수: 6
# 13. ID: 1273  Input Tokens: 1273  Output Tokens: 113   History 수: 7   Question 수: 6
# 14. ID: 1351  Input Tokens: 1282  Output Tokens: 113   History 수: 7   Question 수: 6
# 15. ID: 1083  Input Tokens: 1284  Output Tokens: 151   History 수: 5   Question 수: 8
# 16. ID: 1478  Input Tokens: 1302  Output Tokens: 18   History 수: 11   Question 수: 1
# 17. ID: 1070  Input Tokens: 1324  Output Tokens: 94   History 수: 8   Question 수: 5
# 18. ID: 1267  Input Tokens: 1328  Output Tokens: 75   History 수: 9   Question 수: 4
# 19. ID: 1150  Input Tokens: 1355  Output Tokens: 37   History 수: 11   Question 수: 2
# 20. ID: 1061  Input Tokens: 1377  Output Tokens: 151   History 수: 6   Question 수: 8
# 21. ID: 1105  Input Tokens: 1386  Output Tokens: 189   History 수: 5   Question 수: 10
# 22. ID: 1328  Input Tokens: 1390  Output Tokens: 227   History 수: 3   Question 수: 12
# 23. ID: 1147  Input Tokens: 1406  Output Tokens: 94   History 수: 9   Question 수: 5
# 24. ID: 1374  Input Tokens: 1413  Output Tokens: 94   History 수: 11   Question 수: 5
# 25. ID: 1477  Input Tokens: 1416  Output Tokens: 189   History 수: 4   Question 수: 10
# 26. ID: 1038  Input Tokens: 1422  Output Tokens: 227   History 수: 3   Question 수: 12
# 27. ID: 1433  Input Tokens: 1441  Output Tokens: 170   History 수: 6   Question 수: 9
# 28. ID: 1096  Input Tokens: 1442  Output Tokens: 151   History 수: 6   Question 수: 8
# 29. ID: 1334  Input Tokens: 1462  Output Tokens: 132   History 수: 8   Question 수: 7
# 30. ID: 1275  Input Tokens: 1466  Output Tokens: 75   History 수: 10   Question 수: 4
# 31. ID: 1227  Input Tokens: 1473  Output Tokens: 151   History 수: 7   Question 수: 8
# 32. ID: 1402  Input Tokens: 1483  Output Tokens: 75   History 수: 11   Question 수: 4
# 33. ID: 1463  Input Tokens: 1489  Output Tokens: 113   History 수: 9   Question 수: 6
# 34. ID: 1087  Input Tokens: 1510  Output Tokens: 151   History 수: 7   Question 수: 8
# 35. ID: 1494  Input Tokens: 1527  Output Tokens: 170   History 수: 6   Question 수: 9
# 36. ID: 1365  Input Tokens: 1530  Output Tokens: 151   History 수: 7   Question 수: 8
# 37. ID: 1180  Input Tokens: 1545  Output Tokens: 132   History 수: 8   Question 수: 7
# 38. ID: 1102  Input Tokens: 1558  Output Tokens: 113   History 수: 10   Question 수: 6
# 39. ID: 1487  Input Tokens: 1583  Output Tokens: 113   History 수: 10   Question 수: 6
# 40. ID: 1313  Input Tokens: 1592  Output Tokens: 94   History 수: 11   Question 수: 5
# 41. ID: 1055  Input Tokens: 1594  Output Tokens: 94   History 수: 11   Question 수: 5
# 42. ID: 1047  Input Tokens: 1597  Output Tokens: 151   History 수: 8   Question 수: 8
# 43. ID: 1407  Input Tokens: 1600  Output Tokens: 170   History 수: 7   Question 수: 9
# 44. ID: 1484  Input Tokens: 1600  Output Tokens: 170   History 수: 7   Question 수: 9
# 45. ID: 1369  Input Tokens: 1605  Output Tokens: 189   History 수: 7   Question 수: 10
# 46. ID: 1326  Input Tokens: 1607  Output Tokens: 132   History 수: 9   Question 수: 7
# 47. ID: 1126  Input Tokens: 1617  Output Tokens: 75   History 수: 12   Question 수: 4
# 48. ID: 1400  Input Tokens: 1619  Output Tokens: 75   History 수: 12   Question 수: 4
# 49. ID: 1166  Input Tokens: 1630  Output Tokens: 170   History 수: 7   Question 수: 9
# 50. ID: 1480  Input Tokens: 1643  Output Tokens: 113   History 수: 10   Question 수: 6
#
# Total Input Tokens: 69872
# Total Output Tokens: 6011
#
# list = [1327, 1280, 1448, 1005, 1019, 1044, 1425, 1496, 1295, 1194, 1208, 1074, 1273, 1351, 1083, 1478, 1070, 1267, 1150, 1061, 1105, 1328, 1147, 1374, 1477, 1038, 1433, 1096, 1334, 1275, 1227, 1402, 1463, 1087, 1494, 1365, 1180, 1102, 1487, 1313, 1055, 1047, 1407, 1484, 1369, 1326, 1126, 1400, 1166, 1480]
