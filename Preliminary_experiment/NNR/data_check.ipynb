# %%
import pandas as pd
from IPython.display import display, Markdown

# %% [markdown]
# # Original Data 로드

# %%
# user
filtered_users = pd.read_csv('Adressa_5w_ver2/filtered_user.tsv', sep='\t', names=['User', 'History', 'Train', 'Test'])
filtered_users_test = pd.read_csv('Adressa_5w_ver2/filtered_users_test.tsv', sep='\t', names=['User', 'History', 'Test'])


# news
news_total = pd.read_csv('Adressa_5w/total_news.tsv', sep='\t', names=['News ID', 'Category', 'Sub-Category', 'Title', 'Body', 'ID', 'Publish', 'Click time history'])
news_total_raw = pd.read_csv('Adressa_5w/total_news(raw).tsv', sep='\t', names=['News ID', 'Category', 'Sub-Category', 'Title', 'Body', 'ID', 'Publish', 'Click time history'])


# parsed data
behaviors_parsed = pd.read_csv('Adressa_5w/train/behaviors_parsed_ns8_lt36_3_0.tsv', sep='\t')
news_parsed = pd.read_csv('Adressa_5w/train/news_parsed.tsv', sep='\t')

# 2int
category2int = pd.read_csv('Adressa_5w/train/category2int.tsv', sep='\t')
user2int = pd.read_csv('Adressa_5w/train/user2int.tsv', sep='\t')
word2int = pd.read_csv('Adressa_5w/train/word2int.tsv', sep='\t')

# %% [markdown]
# # Original Data 확인

# %%
display(Markdown("### behaviors_parsed출력<hr/>"))
display(behaviors_parsed)
display(Markdown("### news_parsed출력<hr/>"))
display(news_parsed)
# Out:
# ### behaviors_parsed출력<hr/>
#           user                 time  \
# 0       204423  2017-02-10 02:36:43
# 1        32616  2017-02-10 02:36:43
# 2       115972  2017-02-10 02:36:43
# 3        39838  2017-02-10 02:36:43
# 4         2570  2017-02-10 02:36:43
# ...        ...                  ...
# 514383    5165  2017-02-12 07:59:59
# 514384  229061  2017-02-12 07:59:59
# 514385   88092  2017-02-12 07:59:59
# 514386  135103  2017-02-12 08:00:00
# 514387  162597  2017-02-12 08:00:01
#
#                                              clicked_news  \
# 0
# 1       N16744 N20349 N16747 N17935 N11132 N13014 N178...
# 2       N14684 N9010 N17095 N5701 N8055 N10311 N17617 ...
# 3       N10279 N20336 N18434 N7376 N19903 N7979 N15183...
# 4       N16 N95 N20430 N17785 N16747 N10900 N18557 N18...
# ...                                                   ...
# 514383  N21 N17258 N13517 N4156 N17616 N5161 N19272 N1...
# 514384                                N9403 N18747 N17160
# ...

# %%
display(Markdown("### category2int <hr/>"))
display(category2int)
display(Markdown("### user2int <hr/>"))
display(user2int)
display(Markdown("### word2int <hr/>"))
display(word2int)
# Out:
# ### category2int <hr/>
#        category  int
# 0      100sport    1
# 1         sprek    2
# 2     ballsport    3
# 3       fotball    4
# 4       nyheter    5
# ..          ...  ...
# 122  skandiacup  123
# 123       arkiv  124
# 124      alpint  125
# 125  midt-norge  126
# 126         tdf  127
#
# [127 rows x 2 columns]
# ### user2int <hr/>
#             user     int
# 0        U234611       1
# 1         U23643       2
# 2        U137990       3
# 3         U87587       4
# 4         U93253       5
# ...          ...     ...
# 229056   U398990  229057
# 229057  U1373511  229058
# 229058   U588112  229059
# 229059   U828887  229060
# 229060   U426504  229061
#
# [229061 rows x 2 columns]
# ### word2int <hr/>
#                   word     int
# 0                disse       1
# 1                 fire       2
# 2             øvelsene       3
# 3                  bør       4
# 4                   du       5
# ...                ...     ...
# 330894        halstead  330895
# ...

# %%
display(filtered_users)
display(news_total_raw)
# Out:
#            User                                            History  \
# 0            U1  N2 N2445 N6043 N6053 N5917 N5555 N5733 N5701 N...
# 1            U2  N3 N57 N3374 N5701 N5590 N5874 N5805 N6477 N73...
# 2            U3  N8 N3548 N3394 N3890 N6358 N5336 N4811 N8400 N...
# 3            U4  N9 N11 N14144 N14684 N17088 N17053 N17949 N179...
# 4            U5  N10 N907 N3214 N2932 N2185 N3374 N3395 N3548 N...
# ...         ...                                                ...
# 163541  U163542                               N20769 N20781 N20788
# 163542  U163543                                             N20845
# 163543  U163544                                             N20769
# 163544  U163545                                             N20824
# 163545  U163546                                             N20769
#
#                                                     Train  \
# 0       N21013 N21021 N21756 N21817 N21725 N21821 N218...
# ...

# %%
# Publish 열을 datetime 형식으로 변환 (필수)
news_total_raw["Publish"] = pd.to_datetime(news_total_raw["Publish"])

# Publish 기준 내림차순 정렬
news_total_sorted = news_total_raw.sort_values(by="Publish", ascending=False)

# 결과 확인
news_total_sorted
# Out:
#       News ID  Category  Sub-Category  \
# 24047  N24428   nyheter      utenriks
# 24009  N24390   nyheter  sortrondelag
# 23988  N24369   nyheter     innenriks
# 24001  N24382   nyheter      utenriks
# 23981  N24362  100sport     ballsport
# ...       ...       ...           ...
# 19037  N19346   nyheter     trondheim
# 11930  N12133   nyheter     trondheim
# 16353  N16627  100sport       fotball
# 22670  N23025  100sport       fotball
# 4482    N4580     pluss        serier
#
#                                                    Title  \
# 24047        Minst 19 omkom i bussulykke i Andesfjellene
# 24009      Skrev ut bøter for 35 600 kroner for overlast
# 23988  Oslos byrådsleder mener det er for enkelt å «d...
# 24001            Gullbjørnen til ungarsk kjærlighetsfilm
# 23981  – En glipp av Byåsen først å si ja til million...
# ...                                                  ...
# 19037                       Kniven ligger i hanskerommet
# ...

# %%
display(news_total_sorted[news_total_sorted['News ID']=='N21013'])
display(news_total_sorted[news_total_sorted['News ID']=='N22090'])
# Out:
#       News ID  Category Sub-Category  \
# 20687  N21013  100sport  vintersport
#
#                                             Title  \
# 20687  Northug gjør narr av rivalen etter kollaps
#
#                                                     Body  \
# 20687  Saken oppdateres. LYGNA: Lyn vant, mens det va...
#
#                                              ID             Publish  \
# 20687  96813ce88dc070597d385227d4b85bd424e4105d 2017-02-05 16:11:27
#
#                                       Click time history
# 20687  2017-02-12 08:12:35,2017-02-12 08:31:07,2017-0...
#       News ID  Category   Sub-Category  \
# 21745  N22090  100sport  andreidretter
#
#                                                    Title  \
# 21745  Trump-ordren ødela først for USAs lag – men nå...
#
#                                                     Body  \
# 21745  Saken oppdateres. Fredag annonserte Bahram Qas...
#
#                                              ID             Publish  \
# ...
