# %%
import pandas as pd
import numpy as np

# %%
users = pd.read_csv('experiment_data/LLM/behaviors_user1000_ns4_cdNone.tsv', sep='\t', names=['User', 'History', 'Train'])

# %%
users
# Out:
#        User                                            History  \
# 0         1  N2,2017-01-15 08:00:03;N2445,2017-01-16 00:17:...
# 1         1  N2,2017-01-15 08:00:03;N2445,2017-01-16 00:17:...
# 2         1  N2,2017-01-15 08:00:03;N2445,2017-01-16 00:17:...
# 3         1  N2,2017-01-15 08:00:03;N2445,2017-01-16 00:17:...
# 4         1  N2,2017-01-15 08:00:03;N2445,2017-01-16 00:17:...
# ...     ...                                                ...
# 10984  1000  N10,2017-01-15 08:19:06;N2381,2017-01-16 00:57...
# 10985  1000  N10,2017-01-15 08:19:06;N2381,2017-01-16 00:57...
# 10986  1000  N10,2017-01-15 08:19:06;N2381,2017-01-16 00:57...
# 10987  1000  N10,2017-01-15 08:19:06;N2381,2017-01-16 00:57...
# 10988  1000  N10,2017-01-15 08:19:06;N2381,2017-01-16 00:57...
#
#                                                    Train
# 0      N22972 N23125 N22921 N22933 N23124 N22975 N234...
# 1      N23283 N23035 N23392 N23085 N23019 N23139 N242...
# ...
