# %%
import os
import glob
import random
import pandas as pd
import datetime
import tiktoken
from collections import Counter, defaultdict
from IPython.display import display, Markdown

# user DF에서 History column과 Train column을 합쳐서 history로 사용
file_name = "MIND_LLM.tsv"
user_df = pd.read_csv(f'../../../data/LLM/{file_name}', sep='\t', names=['User', 'History', 'Question'])

news_df = pd.read_csv('../../../data/baseline/MIND_news.tsv', sep='\t', names=['News ID','Category','SubCategory','Title','Abstract','URL','Title Entities','Abstract Entities'])
news_df = news_df.drop(columns=['URL', 'Title Entities', 'Abstract Entities'])

# %%
display(Markdown("### 1. user<hr/>"))
# display(user[user['User']==1]['Question'][0])
display(user_df)
display(Markdown("### 2. NNR_news<hr/>"))
display(news_df)

# %%
start_user=1
max_user=5

# 1) User 범위 필터링
if start_user is not None:
    user_df = user_df[user_df["User"] >= start_user]
if max_user is not None:
    user_df = user_df[user_df["User"] <= max_user]

# %%
user_df

# %%
# 2) 뉴스 ID → 메타정보 dict (news_map)
news_map = {
    row[0]: {"Category": row[1], "SubCategory": row[2],
                "Title": row[3], "Abstract": row[4] if len(row) > 4 else ""}
    for row in news_df.itertuples(index=False)
}

# %%
# 3) 사용자별 히스토리 (순서 유지 & 중복 제거)
user_history_ordered_temp = defaultdict(list)
user_history_temp_set = defaultdict(set)  # 중복 체크용

# %%
def parse_history_list(history_str):
    """문자열 형태의 History를 리스트로 변환"""
    if not isinstance(history_str, str):
        return []
    return [x.strip() for x in history_str.split() if x.strip()]


def parse_question_list(question_str):
    """문자열 형태의 Question(정답 포함) -> 리스트"""
    if not isinstance(question_str, str):
        return []
    return [x.strip() for x in question_str.split() if x.strip()]

# %%
# 사용자별 뉴스 history(클릭 이력)를 중복 없이, 순서를 유지하며 저장
for row in user_df.itertuples(index=False):
    uid = row.User
    hist_list = parse_history_list(row.History)
    for h in hist_list:
        if h not in user_history_temp_set[uid]:
            user_history_ordered_temp[uid].append(h)
            user_history_temp_set[uid].add(h)

# %%
user_history_ordered_temp

# %%
user_history_temp_set

# %%
# dict 변환
user_history_ordered = {uid: lst for uid, lst in user_history_ordered_temp.items()}
user_history_set = {uid: set(lst) for uid, lst in user_history_ordered.items()}

# %%
user_history_ordered

# %%
type(user_history_set)

# %%
category_ns="subcategory"

# 3‑1) 사용자별 카테고리/서브카테고리 클릭 횟수
user_ns_count_map = defaultdict(Counter)
for uid, hist_ids in user_history_set.items():
    ccount = Counter()
    for nid in hist_ids:
        info = news_map.get(nid, {})
        ns_val = info.get("SubCategory" if category_ns == "subcategory" else "Category", None)
        if ns_val:
            ccount[ns_val] += 1
    user_ns_count_map[uid] = ccount

# %%
user_ns_count_map

# %%
news_map.get('N19639', {})

# %%
# 전역 뉴스 집합 (negative 후보군)
global_news_set = set().union(*user_history_set.values())

# %%
global_news_set

# %%
def sample_negatives(
    positive_news_id,
    user_id,
    user_history_set,
    global_news_set,
    user_ns_count_map,
    news_map,
    category_ns="category",  # "category" or "subcategory"
    num_negatives=4
):
    """positive 기사와 동일 user 의 click 카테고리를 고려해 negative 샘플링"""

    # 1) user 가 이미 본 기사 + 현재 positive 제외
    # exclude_set = set(user_history_set[user_id]) | {positive_news_id}
    exclude_set = user_history_set[user_id] 

    candidate_list = []
    for news_id in global_news_set:
        if news_id in exclude_set:
            continue

        info = news_map.get(news_id, {})
        # 카테고리/서브카테고리 값 결정
        ns_val = info.get("SubCategory" if category_ns == "subcategory" else "Category", None)
        if ns_val is None:
            continue

        # 2) 사용자가 해당 카테고리를 이미 2번 이상 본 경우 skip (diversity 확보)
        if user_ns_count_map[user_id].get(ns_val, 0) >= 2:
            continue

        candidate_list.append(news_id)

    state = random.getstate()
    random.seed(user_id)

    # 후보가 부족하면 가능한 만큼만 반환
    result = random.sample(candidate_list, min(len(candidate_list), num_negatives))
    
    random.setstate(state)  # 이전 상태로 복원
    return result


def generate_demonstrations(
    user_id,
    history_ids,
    user_history_set,
    global_news_set,
    news_map,
    user_ns_count_map,
    purpose="with_negative",
    category_use=True,
    subcategory_use=True,
    category_ns="category"
):
    """사용자 히스토리를 natural language 형식으로 변환"""

    if purpose == "only_positive":
        # 클릭 히스토리만 나열
        lines = ["[Click History]",
                 f"User #{user_id}가 과거에 클릭한 뉴스 목록은 다음과 같습니다:\n"]
        for idx, hid in enumerate(history_ids, start=1):
            info = news_map.get(hid, {})    # news_map에서 해당하는 news_id 데이터 추출출
            title = info.get("Title", f"(No Title:{hid})")
            cat = info.get("Category", "unknown")
            subcat = info.get("SubCategory", "unknown")

            # 카테고리/서브카테고리 출력 여부 결정
            if category_use and subcategory_use:
                suffix = f"[category : {cat} | subcategory : {subcat}]"
            elif category_use and not subcategory_use:
                suffix = f"[category : {cat}]"
            elif (not category_use) and subcategory_use:
                suffix = f"[subcategory : {subcat}]"
            else:
                suffix = ""

            lines.append(f"{idx}. {title} {suffix}" if suffix else f"{idx}. {title}")
        lines.append("")
        return lines

    # ---------------- "with_negative" 모드 ----------------
    lines = ["[News of Interest to the user]\n"]

    for idx, hid in enumerate(history_ids, start=1):
        # positive 기사 정보
        pos_info = news_map.get(hid, {})    # news_map에서 해당하는 news_id 데이터 추출출
        pos_title = pos_info.get("Title", f"(No Title:{hid})")
        pos_cat = pos_info.get("Category", "unknown")
        pos_sub = pos_info.get("SubCategory", "unknown")

        # negative 4개 추출
        neg_ids = sample_negatives(
            positive_news_id=hid,
            user_id=user_id,
            user_history_set=user_history_set,
            global_news_set=global_news_set,
            user_ns_count_map=user_ns_count_map,
            news_map=news_map,
            category_ns=category_ns,
            num_negatives=4,
        )

        combined = neg_ids + [hid]
        random.shuffle(combined)  # positive 위치 섞기

        # positive 문장
        if category_use and subcategory_use:
            pos_suffix = f"[category : {pos_cat} | subcategory : {pos_sub}]"
        elif category_use and not subcategory_use:
            pos_suffix = f"[category : {pos_cat}]"
        elif (not category_use) and subcategory_use:
            pos_suffix = f"[subcategory : {pos_sub}]"
        else:
            pos_suffix = ""

        lead = (f"{idx}) User #{user_id} prefers most {pos_title} {pos_suffix} "
                f"among the following 5 articles:")
        lines.append(lead if pos_suffix else lead.replace(pos_suffix, ""))

        # 1 positive + 4 negative 기사 목록
        for i_c, cid in enumerate(combined, start=1):
            cinfo = news_map.get(cid, {})
            ctitle = cinfo.get("Title", f"(No Title:{cid})")
            ccat = cinfo.get("Category", "unknown")
            csub = cinfo.get("SubCategory", "unknown")

            if category_use and subcategory_use:
                suffix = f"[subcategory : {csub}]"
            elif category_use and not subcategory_use:
                suffix = f"[category : {ccat}]"
            elif (not category_use) and subcategory_use:
                suffix = f"[subcategory : {csub}]"
            else:
                suffix = ""
            lines.append(f"{i_c}: {ctitle} {suffix}" if suffix else f"{i_c}: {ctitle}")
        lines.append("")

    return lines

# %%
max_history = None
purpose = 'with_negative'
category_use =False
subcategory_use=True
grouped = user_df.groupby("User")

# %%
for user_id, group in grouped:
    # A) 히스토리 리스트 준비
    hist_list = user_history_ordered[user_id]
    if max_history is not None and len(hist_list) > max_history:
        hist_list = hist_list[-max_history:]  # 최근 기록만 유지

    # 1) 데모 블록 생성
    demo_lines = generate_demonstrations(
        user_id=user_id,
        history_ids=hist_list,
        user_history_set=user_history_set,      # user의 history (중복 제거거)
        global_news_set=global_news_set,        # 전체 뉴스 집합 (test user들이 한 번이라도 클릭했던 news들들)
        news_map=news_map,                      # news 데이터 (dict 형태) 
        user_ns_count_map=user_ns_count_map,    # user history의 category(or subcategory) 분포
        purpose=purpose,
        category_use=category_use,
        subcategory_use=subcategory_use,
        category_ns=category_ns,
    )
    demonstration_text = "\n".join(demo_lines)

    print(f'uid : {user_id}')
    print(demonstration_text)
# Out:
# uid : 1
# [News of Interest to the user]
#
# 1) User #1 prefers most 2020 Chevrolet Corvette C8 vs. C8.R: Here's How the Race Car is Different [subcategory : autossports] among the following 5 articles:
# 1: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 2: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 3: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 4: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 5: 2020 Chevrolet Corvette C8 vs. C8.R: Here's How the Race Car is Different [subcategory : autossports]
#
# 2) User #1 prefers most 'Joker' Continues to Smash Box Office Expectations in 2nd Weekend [subcategory : movienews] among the following 5 articles:
# 1: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 2: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 3: 'Joker' Continues to Smash Box Office Expectations in 2nd Weekend [subcategory : movienews]
# 4: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 5: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
#
# 3) User #1 prefers most Boxer Patrick Day dies after suffering traumatic brain injury in super welterweight fight [subcategory : boxing] among the following 5 articles:
# 1: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 2: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 3: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 4: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 5: Boxer Patrick Day dies after suffering traumatic brain injury in super welterweight fight [subcategory : boxing]
#
# 4) User #1 prefers most Former NFL lineman Justin Bannan arrested for attempted murder [subcategory : football_nfl] among the following 5 articles:
# 1: Former NFL lineman Justin Bannan arrested for attempted murder [subcategory : football_nfl]
# 2: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 3: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 4: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 5: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
#
# 5) User #1 prefers most Silver: China requested for Rockets' Morey to be fired [subcategory : basketball_nba] among the following 5 articles:
# 1: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 2: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 3: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 4: Silver: China requested for Rockets' Morey to be fired [subcategory : basketball_nba]
# 5: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
#
# 6) User #1 prefers most Video Of A Young Boy's Sweet Words To A Fish He Released Is Melting Hearts [subcategory : newsgoodnews] among the following 5 articles:
# 1: Video Of A Young Boy's Sweet Words To A Fish He Released Is Melting Hearts [subcategory : newsgoodnews]
# 2: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 3: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 4: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 5: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
#
# 7) User #1 prefers most As U.S. Leaves Allies in Syria, Kurdish Commander Struggles With Fallout [subcategory : newsworld] among the following 5 articles:
# 1: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 2: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 3: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 4: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 5: As U.S. Leaves Allies in Syria, Kurdish Commander Struggles With Fallout [subcategory : newsworld]
#
# 8) User #1 prefers most NFL Week 7 Awards: Is this the best photo ever taken of a NFL player? [subcategory : football_nfl] among the following 5 articles:
# 1: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 2: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 3: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 4: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 5: NFL Week 7 Awards: Is this the best photo ever taken of a NFL player? [subcategory : football_nfl]
#
# 9) User #1 prefers most NFL Week 9 Power Rankings: More ammo for Belichick as greatest coach ever [subcategory : football_nfl] among the following 5 articles:
# 1: NFL Week 9 Power Rankings: More ammo for Belichick as greatest coach ever [subcategory : football_nfl]
# 2: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 3: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 4: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 5: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
#
# 10) User #1 prefers most Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer] among the following 5 articles:
# 1: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 2: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 3: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 4: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 11) User #1 prefers most Inside the Sheikh of Dubai's 800-acre Kentucky horse farm [subcategory : finance-real-estate] among the following 5 articles:
# 1: Robert Evans, 'Chinatown' Producer and Paramount Chief, Dies at 89 [subcategory : movienews]
# 2: Tom Draper, Black Music Industry Pioneer, Dies at 79 [subcategory : musicnews]
# 3: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
# 4: Inside the Sheikh of Dubai's 800-acre Kentucky horse farm [subcategory : finance-real-estate]
# 5: This is the best exercise to pump up aging muscles [subcategory : fitness]
#
# uid : 2
# [News of Interest to the user]
#
# 1) User #2 prefers most Prince William and Kate Middleton arrive in Pakistan for royal tour [subcategory : lifestyleroyals] among the following 5 articles:
# 1: Prince William and Kate Middleton arrive in Pakistan for royal tour [subcategory : lifestyleroyals]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 2) User #2 prefers most See all the best photos of Prince William and Duchess Kate's royal tour of Pakistan [subcategory : lifestyleroyals] among the following 5 articles:
# 1: See all the best photos of Prince William and Duchess Kate's royal tour of Pakistan [subcategory : lifestyleroyals]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 3) User #2 prefers most 6 Signs You're Not Getting Enough Potassium [subcategory : nutrition] among the following 5 articles:
# 1: 6 Signs You're Not Getting Enough Potassium [subcategory : nutrition]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 4) User #2 prefers most Man sets pet lion on electrician who tried to collect pay, police say [subcategory : newsworld] among the following 5 articles:
# 1: Man sets pet lion on electrician who tried to collect pay, police say [subcategory : newsworld]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 5: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
#
# 5) User #2 prefers most 12 things that could save us money if we weren't lazy [subcategory : finance-savemoney] among the following 5 articles:
# 1: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: 12 things that could save us money if we weren't lazy [subcategory : finance-savemoney]
# 5: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
#
# 6) User #2 prefers most Unprecedented movement detected on California earthquake fault capable of 8.0 temblor [subcategory : newsus] among the following 5 articles:
# 1: Unprecedented movement detected on California earthquake fault capable of 8.0 temblor [subcategory : newsus]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 7) User #2 prefers most France says foiled September 11-inspired attack [subcategory : newsworld] among the following 5 articles:
# 1: France says foiled September 11-inspired attack [subcategory : newsworld]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
#
# 8) User #2 prefers most These 4 words are the key to becoming rich [subcategory : newsus] among the following 5 articles:
# 1: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: These 4 words are the key to becoming rich [subcategory : newsus]
# 4: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 9) User #2 prefers most 7 Surprising Features That Boost Your Home Value [subcategory : finance-real-estate] among the following 5 articles:
# 1: 7 Surprising Features That Boost Your Home Value [subcategory : finance-real-estate]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 10) User #2 prefers most 30 Funny Dog Photos You Need to See [subcategory : lifestylepetsanimals] among the following 5 articles:
# 1: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: 30 Funny Dog Photos You Need to See [subcategory : lifestylepetsanimals]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 11) User #2 prefers most This is the best exercise to pump up aging muscles [subcategory : fitness] among the following 5 articles:
# 1: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: This is the best exercise to pump up aging muscles [subcategory : fitness]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 12) User #2 prefers most Bag Explodes While Being Loaded On Volaris Flight At Midway Airport [subcategory : travelnews] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Bag Explodes While Being Loaded On Volaris Flight At Midway Airport [subcategory : travelnews]
# 4: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 13) User #2 prefers most Reduce Stomach Bloating: 9 Daily Habits That Flatten Your Belly [subcategory : wellness] among the following 5 articles:
# 1: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: Reduce Stomach Bloating: 9 Daily Habits That Flatten Your Belly [subcategory : wellness]
# 4: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 14) User #2 prefers most Duchess Meghan Returns to Public Eye After Africa Tour Documentary Airs [subcategory : lifestyleroyals] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: Duchess Meghan Returns to Public Eye After Africa Tour Documentary Airs [subcategory : lifestyleroyals]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 15) User #2 prefers most Body of missing Alabama girl found; 2 being charged [subcategory : newscrime] among the following 5 articles:
# 1: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Body of missing Alabama girl found; 2 being charged [subcategory : newscrime]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 16) User #2 prefers most Why Healthy People Faint and How to Treat Them [subcategory : medical] among the following 5 articles:
# 1: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: Why Healthy People Faint and How to Treat Them [subcategory : medical]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 17) User #2 prefers most 2 passengers, emotional support French bulldogs booted off Norwegian Air flight [subcategory : travelnews] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: 2 passengers, emotional support French bulldogs booted off Norwegian Air flight [subcategory : travelnews]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
#
# 18) User #2 prefers most 10 Exercises You Should Never Do Again, According to Trainers [subcategory : fitness] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: 10 Exercises You Should Never Do Again, According to Trainers [subcategory : fitness]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 19) User #2 prefers most Six photographers share their favorite Audrey Hepburn images in a new book celebrating the Hollywood actress 26 years after her death [subcategory : movies-celebrity] among the following 5 articles:
# 1: Six photographers share their favorite Audrey Hepburn images in a new book celebrating the Hollywood actress 26 years after her death [subcategory : movies-celebrity]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 20) User #2 prefers most Florida needs python hunters. A man in Iran is one of thousands applying for the job [subcategory : newsus] among the following 5 articles:
# 1: Florida needs python hunters. A man in Iran is one of thousands applying for the job [subcategory : newsus]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
#
# 21) User #2 prefers most 14 Bad Habits You Can Break Right Now to Live Your Best Life [subcategory : wellness] among the following 5 articles:
# 1: 14 Bad Habits You Can Break Right Now to Live Your Best Life [subcategory : wellness]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 22) User #2 prefers most What it's like to cook for Kate Middleton and Prince William, according to Giada De Laurentiis [subcategory : foodnews] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: What it's like to cook for Kate Middleton and Prince William, according to Giada De Laurentiis [subcategory : foodnews]
#
# 23) User #2 prefers most 5 signs it's time to find a new nail salon [subcategory : lifestylebeauty] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: 5 signs it's time to find a new nail salon [subcategory : lifestylebeauty]
#
# 24) User #2 prefers most Multiple Houses on Fire After Plane Crashes in NJ [subcategory : newsus] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Multiple Houses on Fire After Plane Crashes in NJ [subcategory : newsus]
# 4: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 25) User #2 prefers most Most adults over 50 would rather die than do this [subcategory : finance-healthcare] among the following 5 articles:
# 1: Most adults over 50 would rather die than do this [subcategory : finance-healthcare]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 26) User #2 prefers most 4 Reasons You Should See Your Gynecologist Every Year [subcategory : medical] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: 4 Reasons You Should See Your Gynecologist Every Year [subcategory : medical]
# 5: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
#
# 27) User #2 prefers most Heidi Klum's 2019 Halloween Costume Transformation Is Mind-Blowing   But, Like, What Is It? [subcategory : lifestylebuzz] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: Heidi Klum's 2019 Halloween Costume Transformation Is Mind-Blowing   But, Like, What Is It? [subcategory : lifestylebuzz]
# 4: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 5: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
#
# 28) User #2 prefers most Unexpected Signs of an Unhealthy Heart [subcategory : medical] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: Unexpected Signs of an Unhealthy Heart [subcategory : medical]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 29) User #2 prefers most Debunking the week's tabloid stories: Nov. 1, 2019 [subcategory : celebrity] among the following 5 articles:
# 1: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: Debunking the week's tabloid stories: Nov. 1, 2019 [subcategory : celebrity]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 30) User #2 prefers most Meghan Markle Says She Doesn't Want People to Love Her, She Wants Them to Hear Her [subcategory : lifestyleroyals] among the following 5 articles:
# 1: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 2: Meghan Markle Says She Doesn't Want People to Love Her, She Wants Them to Hear Her [subcategory : lifestyleroyals]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 31) User #2 prefers most 24 Ways to Shrink Your Belly in 24 Hours [subcategory : weightloss] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: 24 Ways to Shrink Your Belly in 24 Hours [subcategory : weightloss]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 32) User #2 prefers most Here's Exactly What Kristen Bell Eats in a Day to Make 39 Look Like 29 [subcategory : nutrition] among the following 5 articles:
# 1: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: Here's Exactly What Kristen Bell Eats in a Day to Make 39 Look Like 29 [subcategory : nutrition]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 33) User #2 prefers most My Doctors Told Me I Had IBS. 4 Years Later, I Found out It Was a Completely Different Disorder [subcategory : voices] among the following 5 articles:
# 1: My Doctors Told Me I Had IBS. 4 Years Later, I Found out It Was a Completely Different Disorder [subcategory : voices]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 34) User #2 prefers most Jess Lost 75 Pounds Without Counting Calories and Did This 1 Inspiring Thing Before Every Meal [subcategory : weightloss] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: Jess Lost 75 Pounds Without Counting Calories and Did This 1 Inspiring Thing Before Every Meal [subcategory : weightloss]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 35) User #2 prefers most Prince Harry Has the Sweetest Response When Young Student Calls Him Handsome During Japan Trip [subcategory : lifestyleroyals] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Prince Harry Has the Sweetest Response When Young Student Calls Him Handsome During Japan Trip [subcategory : lifestyleroyals]
#
# 36) User #2 prefers most Woman found dead in Ohio home was likely killed by her Great Danes, police say [subcategory : newsus] among the following 5 articles:
# 1: Woman found dead in Ohio home was likely killed by her Great Danes, police say [subcategory : newsus]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 37) User #2 prefers most The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: The Water on These Airlines Is so Bad You Shouldn't Even Wash Your Hands With It, Study Finds [subcategory : travelnews]
#
# 38) User #2 prefers most This is how much water you need to drink for weight loss [subcategory : nutrition] among the following 5 articles:
# 1: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: This is how much water you need to drink for weight loss [subcategory : nutrition]
# 4: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
#
# 39) User #2 prefers most Elephant dies of 'exhaustion' from carrying tourists in Sri Lanka [subcategory : travelnews] among the following 5 articles:
# 1: Elephant dies of 'exhaustion' from carrying tourists in Sri Lanka [subcategory : travelnews]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 40) User #2 prefers most This Simple Hack Will Keep Spiders Out of Your House [subcategory : lifestylesmartliving] among the following 5 articles:
# 1: This Simple Hack Will Keep Spiders Out of Your House [subcategory : lifestylesmartliving]
# 2: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 41) User #2 prefers most Family Members Plead for Help in Search for Missing Atlanta College Student: 'Just Come Home' [subcategory : newsus] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: Family Members Plead for Help in Search for Missing Atlanta College Student: 'Just Come Home' [subcategory : newsus]
# 4: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 5: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
#
# 42) User #2 prefers most Prince Harry and Meghan Markle are taking a royal respite [subcategory : lifestyleroyals] among the following 5 articles:
# 1: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 2: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 3: Prince Harry and Meghan Markle are taking a royal respite [subcategory : lifestyleroyals]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
#
# 43) User #2 prefers most Already 6 Months! Prince Harry, Duchess Meghan's Son Is Trying to Talk [subcategory : lifestyleroyals] among the following 5 articles:
# 1: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 2: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 3: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 4: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 5: Already 6 Months! Prince Harry, Duchess Meghan's Son Is Trying to Talk [subcategory : lifestyleroyals]
#
# 44) User #2 prefers most Australian tourist killed by elephant in Namibia [subcategory : newsworld] among the following 5 articles:
# 1: 17 photos that show the ugly truth of living in a tiny house [subcategory : lifestylehomeandgarden]
# 2: Presidential election model that got it wrong once in 40 years predicts Trump 2020 win [subcategory : newspolitics]
# 3: Former NBA first-round pick Jim Farmer arrested in sex sting operation [subcategory : basketball_nba]
# 4: Australian tourist killed by elephant in Namibia [subcategory : newsworld]
# 5: Pregnant U.S. women's soccer star Alex Morgan still plans to play in 2020 Summer Olympics [subcategory : soccer]
# 5: Duchess Meghan Returns to Public Eye After Africa Tour Documentary Airs [subcategory : lifestyleroyals]
#
# 27) User #5 prefers most Dez Bryant plans to reach out to NFL teams in two weeks [subcategory : football_nfl] among the following 5 articles:
# 1: Dez Bryant plans to reach out to NFL teams in two weeks [subcategory : football_nfl]
# 2: Duchess Meghan Returns to Public Eye After Africa Tour Documentary Airs [subcategory : lifestyleroyals]
# 3: 4 Reasons You Should See Your Gynecologist Every Year [subcategory : medical]
# 4: Already 6 Months! Prince Harry, Duchess Meghan's Son Is Trying to Talk [subcategory : lifestyleroyals]
# 5: What it's like to cook for Kate Middleton and Prince William, according to Giada De Laurentiis [subcategory : foodnews]
#
# 28) User #5 prefers most Trump to spend $300 million on border wall "quality assurance" [subcategory : newsus] among the following 5 articles:
# 1: What it's like to cook for Kate Middleton and Prince William, according to Giada De Laurentiis [subcategory : foodnews]
# 2: 4 Reasons You Should See Your Gynecologist Every Year [subcategory : medical]
# 3: Trump to spend $300 million on border wall "quality assurance" [subcategory : newsus]
# 4: Already 6 Months! Prince Harry, Duchess Meghan's Son Is Trying to Talk [subcategory : lifestyleroyals]
# 5: Duchess Meghan Returns to Public Eye After Africa Tour Documentary Airs [subcategory : lifestyleroyals]

# %%
for user_id, group in grouped:
    # A) 히스토리 리스트 준비
    hist_list = user_history_ordered[user_id]
    if max_history is not None and len(hist_list) > max_history:
        hist_list = hist_list[-max_history:]  # 최근 기록만 유지
    print(hist_list)

# %%
type(user_history_set)

# %%
def split_into_chunks(seq, n):
    """seq를 n등분(앞쪽에 나머지 분배)한 리스트리스트 반환"""
    if n > len(seq):
        n = len(seq)
    base = len(seq) // n
    rem  = len(seq) % n
    sizes = [base + 1 if i < rem else base for i in range(n)]
    out, idx = [], 0
    for s in sizes:
        out.append(seq[idx:idx+s])
        idx += s
    return [c for c in out if c]

seq = ['N58584', 'N12900', 'N6233', 'N51706', 'N18777', 'N593', 'N16793', 'N846', 'N18285', 'N46846', 'N53436']

split_into_chunks(seq, 5)
# Out:
# [['N58584', 'N12900', 'N6233'],
#  ['N51706', 'N18777'],
#  ['N593', 'N16793'],
#  ['N846', 'N18285'],
#  ['N46846', 'N53436']]

# %%
def split_into_chunks(seq, n, min_num=1):
    """seq를 n등분하되, 각 chunk는 최소 min_num 이상의 길이를 가져야 함. 불가능하면 n보다 적게 나눔"""
    if not seq:
        return []

    max_possible_chunks = len(seq) // min_num
    n = min(n, max_possible_chunks) if max_possible_chunks > 0 else 1

    base = len(seq) // n
    rem  = len(seq) % n
    sizes = [base + 1 if i < rem else base for i in range(n)]

    out, idx = [], 0
    for s in sizes:
        out.append(seq[idx:idx+s])
        idx += s

    return [c for c in out if c]

seq = ['N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'N9', 'N10', 'N11', 'N12', 'N13', 'N14']
print(split_into_chunks(seq, 5, min_num=3))
# Out:
# [['N1', 'N2', 'N3', 'N4'], ['N5', 'N6', 'N7', 'N8'], ['N9', 'N10', 'N11'], ['N12', 'N13', 'N14']]
